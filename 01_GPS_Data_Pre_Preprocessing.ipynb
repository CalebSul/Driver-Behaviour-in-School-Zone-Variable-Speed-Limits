# %%
# Import necessary packages
import pandas as pd
import os
import glob

# %% [markdown]
# # 1) Find columns in GPS data

# %%
# Load in only column names of GPS data in memory (cannot load full 9GB dataset)
df = pd.read_csv(f'GPS_Data/caleb_AOI_full_traces.tsv', sep='\t', nrows=0)
print(df.columns.tolist())
# Out:
# ['Country', 'Hashed_ID', 'lat', 'lon', 'Unix_Time']

# %% [markdown]
# # 2) Order tsv file by user id and unix time in Git Bash
#
# Order TSV by user ID and unix time based on column locations found above and save ordered GPS data:
#
# (head -n 1 "Input_File_Location" && \
#  tail -n +2 "Input_File_Location" | \
#  sort -t $'\t' -k2,2 -k5,5n --parallel=10) > "Output_File_Location"
#
# Row 2 is hashed ID and row 5 is unix time.
#
# File contains 118,431,864 rows (found using: wc -l file_location.tsv in Git Bash)
#
# The file contains 14,179 unique Hashed_IDs within the dataset
#
# Dataset ranges from July 20th 2020 00:00:00 NZT to December 1st 2020 11:59:58 NZT
#
# These values were found via: cut f(row num) file_location.tsv | sourt -u -- parallel=10 | wc -l

# %% [markdown]
# # 3) Split dataset into ~1 million row chunks for memory management

# %%
# Define filepath to tsv and output directory
input_file = "GPS_Data/AOI_sorted_traces.tsv"
output_folder = "GPS_Data/Chunks"

# Create output directory
os.makedirs(output_folder, exist_ok=True)

chunksize = 1_000_000 # Number of rows per chunk
chunk_num = 1 # Chunk counter to be updated
current_chunk = []  # will hold rows for the current output chunk
carryover_rows = []  # rows that must be carried over to next chunk

# Read TSV in chunks
for chunk in pd.read_csv(input_file, sep='\t', chunksize=chunksize, dtype=str):
    
    # Add carryover rows from previous chunk to current chunk
    if carryover_rows:
        chunk = pd.concat([pd.DataFrame(carryover_rows), chunk], ignore_index=True)
        carryover_rows = []

    # Determine rows where Hashed_ID changes and save locations
    hashed_ids = chunk['Hashed_ID']
    change_points = hashed_ids.ne(hashed_ids.shift()).to_numpy().nonzero()[0]

    start_idx = 0
    # Loop over change points
    for idx in change_points[1:]:
        # Find if distance from current hashed_id change row to start row is larger than desired chunksize
        if idx - start_idx >= chunksize:
            # Slice data from start_idx to idx
            chunk_to_save = chunk.iloc[start_idx:idx]

            # Save slice containing all hashed_id data
            output_path = os.path.join(output_folder, f"GPS_Data_Chunk_{chunk_num}.tsv")
            chunk_to_save.to_csv(output_path, sep='\t', index=False)
            print(f"Saved {output_path} with {len(chunk_to_save)} rows")
            
            chunk_num += 1 #update chunk number counter
            start_idx = idx # update start_idx value

    # Any remaining rows go into carryover for next iteration
    carryover_rows = chunk.iloc[start_idx:].to_dict('records')

# Save any remaining rows
if carryover_rows:
    chunk_df = pd.DataFrame(carryover_rows)
    output_path = os.path.join(output_folder, f"GPS_Data_Chunk_{chunk_num}.tsv")
    chunk_df.to_csv(output_path, sep='\t', index=False)
    print(f"Saved {output_path} with {len(chunk_df)} rows")
# Out:
# Saved GPS_Data/Chunks\GPS_Data_Chunk_1.tsv with 1030944 rows
# Saved GPS_Data/Chunks\GPS_Data_Chunk
rows
# Saved GPS_Data/Chunks\GPS_Data_Chunk_101.tsv with 1009572 rows
# Saved GPS_Data/Chunks\GPS_Data_Chunk_102.tsv with 1006289 rows
# Saved GPS_Data/Chunks\GPS_Data_Chunk_103.tsv with 1012569 rows
# Saved GPS_Data/Chunks\GPS_Data_Chunk_104.tsv with 1001022 rows
# Saved GPS_Data/Chunks\GPS_Data_Chunk_105.tsv with 1008520 rows
# Saved GPS_Data/Chunks\GPS_Data_Chunk_106.tsv with 1007606 rows
# Saved GPS_Data/Chunks\GPS_Data_Chunk_107.tsv with 1045255 rows
# Saved GPS_Data/Chunks\GPS_Data_Chunk_108.tsv with 1033893 rows
# Saved GPS_Data/Chunks\GPS_Data_Chunk_109.tsv with 1043705 rows
# Saved GPS_Data/Chunks\GPS_Data_Chunk_110.tsv with 1015680 rows
# Saved GPS_Data/Chunks\GPS_Data_Chunk_111.tsv with 1020245 rows
# Saved GPS_Data/Chunks\GPS_Data_Chunk_112.tsv with 1000237 rows
# Saved GPS_Data/Chunks\GPS_Data_Chunk_113.tsv with 1005480 rows
# Saved GPS_Data/Chunks\GPS_Data_Chunk_114.tsv with 1004742 rows
# Saved GPS_Data/Chunks\GPS_Data_Chunk_115.tsv with 1019717 rows
# Saved GPS_Data/Chunks\GPS_Data_Chunk_116.tsv with 1012728 rows
# Saved GPS_Data/Chunks\GPS_Data_Chunk_117.tsv with 175158 rows

# %% [markdown]
# # 4) Get aggregated stats by hashed ID

# %%
# Define file paths
chunk_folder = "GPS_Data/Chunks"
output_file = "GPS_Data/Hashed_ID_Summary.csv"

# List all chunk files
chunk_files = sorted(glob.glob(os.path.join(chunk_folder, "GPS_Data_Chunk_*.tsv")))

# Initialize a list to collect summariesT
all_summaries = []

for chunk_file in chunk_files:
    print(f"Processing {chunk_file} ...")
    # Extract chunk number
    digits = [char for char in chunk_file if char.isdigit()]
    chunk_num = int(''.join(digits))
    
    # Load the chunk and group by hashed id
    df = pd.read_csv(chunk_file, sep='\t')
    grouped = df.groupby('Hashed_ID')
    
    # Find key info by hashed ID
    summary = grouped.agg(
    num_rows=('Hashed_ID', 'size'),
    min_unix_time=('Unix_Time', 'min'),
    max_unix_time=('Unix_Time', 'max')
    ).reset_index()

    summary['TSV'] = chunk_num
    
    # Append summary variable to the all_summaries list
    all_summaries.append(summary)

# Convert all cummaries into a dataframe
final_summary = pd.concat(all_summaries, ignore_index=True)

# Save to CSV
final_summary.to_csv(output_file, index=False)
print(f"Final summary saved to {output_file}")
# Out:
# Processing GPS_Data/Chunks\GPS_Data_Chunk_1.tsv ...
# Processing GPS_Data/Chunks\GPS_Data_Chunk_10.tsv ...
# Processing GPS_Data/Chunks\GPS_Data_Chunk_100.tsv ...
# Processing GPS_Data/Chunks\GPS_Data_Chunk_101.tsv ...
# Processing GPS_Data/Chunks\GPS_Data_Chunk_102.tsv ...
# Processing GPS_Data/Chunks\GPS_Data_Chunk_103.tsv ...
# Processing GPS_Data/Chunks\GPS_Data_Chunk_104.tsv ...
# Processing GPS_Data/Chunks\GPS_Data_Chunk_105.tsv ...
# Processing GPS_Data/Chunks\GPS_Data_Chunk_106.tsv ...
# Processing GPS_Data/Chunks\GPS_Data_Chunk_107.tsv ...
# Processing GPS_Data/Chunks\GPS_Data_Chunk_108.tsv ...
# Processing GPS_Data/Chunks\GPS_Data_Chunk_109.tsv ...
# Processing GPS_Data/Chunks\GPS_Data_Chunk_11.tsv ...
# Processing GPS_Data/Chunks\GPS_Data_Chunk_110.tsv ...
# Processing GPS_Data/Chunks\GPS_Data_Chunk_111.tsv ...
# Processing GPS_Data/Chunks\GPS_Data_Chunk_112.tsv ...
# Processing GPS_Data/Chunks\GPS_Data_Chunk_113.tsv ...
# Processing GPS_Data/Chunks\GPS_Data_Chunk_114.tsv ...
# Processing GPS_Data/Chunks\GPS_Data_Chunk_115.tsv ...
# Processing GPS_Data/Chunks\GPS_Data_Chunk_116.tsv ...
# Processing GPS_Data/Chunks\GPS_Data_Chunk_117.tsv ...
# Processing GPS_Data/Chunks\GPS_Data_Chunk_12.tsv ...
# Processing GPS_Data/Chunks\GPS_Data_Chunk_13.tsv ...
# Processing GPS_Data/Chunks\GPS_Data_Chunk_14.tsv ...
# Processing GPS_Data/Chunks\GPS_Data_Chunk_15.tsv ...
# Processing GPS_Data/Chunks\GPS_Data_Chunk_16.tsv ...
# Processing GPS_Data/Chunks\GPS_Data_Chunk_17.tsv ...
# Processing GPS_Data/Chunks\GPS_Data_Chunk_18.tsv ...
# Processing GPS_Data/Chunks\GPS_Data_Chunk_19.tsv ...
# Processing GPS_Data/Chunks\GPS_Data_Chunk_2.tsv ...
# Processing GPS_Data/Chunks\GPS_Data_Chunk_20.tsv ...
# Processing GPS_Data/Chunks\GPS_Data_Chunk_21.tsv ...
# Processing GPS_Data/Chunks\GPS_Data_Chunk_22.tsv ...
# Processing GPS_Data/Chunks\GPS_Data_Chunk_23.tsv ...
# Processing GPS_Data/Chunks\GPS_Data_Chunk_24.tsv ...
# Processing GPS_Data/Chunks\GPS_Data_Chunk_25.tsv ...
# Processing GPS_Data/Chunks\GPS_Data_Chunk_26.tsv ...
# Processing GPS_Data/Chunks\GPS_Data_Chunk_27.tsv ...
# Processing GPS_Data/Chunks\GPS_Data_Chunk_28.tsv ...
# Processing GPS_Data/Chunks\GPS_Data_Chunk_29.tsv ...
# Processing GPS_Data/Chunks\GPS_Data_Chunk_3.tsv ...
# Processing GPS_Data/Chunks\GPS_Data_Chunk_30.tsv ...
# Processing GPS_Data/Chunks\GPS_Data_Chunk_31.tsv ...
# Processing GPS_Data/Chunks\GPS_Data_Chunk_32.tsv ...
# Processing GPS_Data/Chunks\GPS_Data_Chunk_33.tsv ...
# Processing GPS_Data/Chunks\GPS_Data_Chunk_34.tsv ...
# Processing GPS_Data/Chunks\GPS_Data_Chunk_35.tsv ...
# Processing GPS_Data/Chunks\GPS_Data_Chunk_36.tsv ...
# Processing GPS_Data/Chunks\GPS_Data_Chunk_37.tsv ...
# Processing GPS_Data/Chunks\GPS_Data_Chunk_38.tsv ...
# Processing GPS_Data/Chunks\GPS_Data_Chunk_39.tsv ...
# Processing GPS_Data/Chunks\GPS_Data_Chunk_4.tsv ...
# Processing GPS_Data/Chunks\GPS_Data_Chunk_40.tsv ...
# Processing GPS_Data/Chunks\GPS_Data_Chunk_41.tsv ...
# Processing GPS_Data/Chunks\GPS_Data_Chunk_42.tsv ...
# Processing GPS_Data/Chunks\GPS_Data_Chunk_43.tsv ...
# Processing GPS_Data/Chunks\GPS_Data_Chunk_44.tsv ...
# Processing GPS_Data/Chunks\GPS_Data_Chunk_45.tsv ...
# Processing GPS_Data/Chunks\GPS_Data_Chunk_46.tsv ...
# Processing GPS_Data/Chunks\GPS_Data_Chunk_47.tsv ...
# Processing GPS_Data/Chunks\GPS_Data_Chunk_48.tsv ...
# Processing GPS_Data/Chunks\GPS_Data_Chunk_49.tsv ...
# Processing GPS_Data/Chunks\GPS_Data_Chunk_5.tsv ...
# Processing GPS_Data/Chunks\GPS_Data_Chunk_50.tsv ...
# Processing GPS_Data/Chunks\GPS_Data_Chunk_51.tsv ...
# Processing GPS_Data/Chunks\GPS_Data_Chunk_52.tsv ...
# Processing GPS_Data/Chunks\GPS_Data_Chunk_53.tsv ...
# Processing GPS_Data/Chunks\GPS_Data_Chunk_54.tsv ...
# Processing GPS_Data/Chunks\GPS_Data_Chunk_55.tsv ...
# Processing GPS_Data/Chunks\GPS_Data_Chunk_56.tsv ...
# Processing GPS_Data/Chunks\GPS_Data_Chunk_57.tsv ...
# Processing GPS_Data/Chunks\GPS_Data_Chunk_58.tsv ...
# Processing GPS_Data/Chunks\GPS_Data_Chunk_59.tsv ...
# Processing GPS_Data/Chunks\GPS_Data_Chunk_6.tsv ...
# Processing GPS_Data/Chunks\GPS_Data_Chunk_60.tsv ...
# Processing GPS_Data/Chunks\GPS_Data_Chunk_61.tsv ...
# Processing GPS_Data/Chunks\GPS_Data_Chunk_62.tsv ...
# Processing GPS_Data/Chunks\GPS_Data_Chunk_63.tsv ...
# Processing GPS_Data/Chunks\GPS_Data_Chunk_64.tsv ...
# Processing GPS_Data/Chunks\GPS_Data_Chunk_65.tsv ...
# Processing GPS_Data/Chunks\GPS_Data_Chunk_66.tsv ...
# Processing GPS_Data/Chunks\GPS_Data_Chunk_67.tsv ...
# Processing GPS_Data/Chunks\GPS_Data_Chunk_68.tsv ...
# Processing GPS_Data/Chunks\GPS_Data_Chunk_69.tsv ...
# Processing GPS_Data/Chunks\GPS_Data_Chunk_7.tsv ...
# Processing GPS_Data/Chunks\GPS_Data_Chunk_70.tsv ...
# Processing GPS_Data/Chunks\GPS_Data_Chunk_71.tsv ...
# Processing GPS_Data/Chunks\GPS_Data_Chunk_72.tsv ...
# Processing GPS_Data/Chunks\GPS_Data_Chunk_73.tsv ...
# Processing GPS_Data/Chunks\GPS_Data_Chunk_74.tsv ...
# Processing GPS_Data/Chunks\GPS_Data_Chunk_75.tsv ...
# Processing GPS_Data/Chunks\GPS_Data_Chunk_76.tsv ...
# Processing GPS_Data/Chunks\GPS_Data_Chunk_77.tsv ...
# Processing GPS_Data/Chunks\GPS_Data_Chunk_78.tsv ...
# Processing GPS_Data/Chunks\GPS_Data_Chunk_79.tsv ...
# Processing GPS_Data/Chunks\GPS_Data_Chunk_8.tsv ...
# Processing GPS_Data/Chunks\GPS_Data_Chunk_80.tsv ...
# Processing GPS_Data/Chunks\GPS_Data_Chunk_81.tsv ...
# Processing GPS_Data/Chunks\GPS_Data_Chunk_82.tsv ...
# Processing GPS_Data/Chunks\GPS_Data_Chunk_83.tsv ...
# Processing GPS_Data/Chunks\GPS_Data_Chunk_84.tsv ...
# Processing GPS_Data/Chunks\GPS_Data_Chunk_85.tsv ...
# Processing GPS_Data/Chunks\GPS_Data_Chunk_86.tsv ...
# Processing GPS_Data/Chunks\GPS_Data_Chunk_87.tsv ...
# Processing GPS_Data/Chunks\GPS_Data_Chunk_88.tsv ...
# Processing GPS_Data/Chunks\GPS_Data_Chunk_89.tsv ...
# Processing GPS_Data/Chunks\GPS_Data_Chunk_9.tsv ...
# Processing GPS_Data/Chunks\GPS_Data_Chunk_90.tsv ...
# Processing GPS_Data/Chunks\GPS_Data_Chunk_91.tsv ...
# Processing GPS_Data/Chunks\GPS_Data_Chunk_92.tsv ...
# Processing GPS_Data/Chunks\GPS_Data_Chunk_93.tsv ...
# Processing GPS_Data/Chunks\GPS_Data_Chunk_94.tsv ...
# Processing GPS_Data/Chunks\GPS_Data_Chunk_95.tsv ...
# Processing GPS_Data/Chunks\GPS_Data_Chunk_96.tsv ...
# Processing GPS_Data/Chunks\GPS_Data_Chunk_97.tsv ...
# Processing GPS_Data/Chunks\GPS_Data_Chunk_98.tsv ...
# Processing GPS_Data/Chunks\GPS_Data_Chunk_99.tsv ...
# Final summary saved to GPS_Data/Hashed_ID_Summary.csv
